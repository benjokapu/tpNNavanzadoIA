# %% [markdown]
# # Trabajo Práctico Redes Neuronales

# %% [markdown]
# Trabajo Práctico hecho por Benjamin Kapustiansky y Oliver Safdieh

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install random
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for random

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from random import random as rand
import itertools

# %%
archivo = "dataset_frutas.csv"

# Leer datos del archivo
frutas : pd.DataFrame = pd.read_csv(archivo)
frutas
# Out:
#            Peso      Color    Tamaño  Ácida  Dulce  Tropical
# 0    202.921570       Rojo  5.666598      0      1         1
# 1    162.004716      Verde  8.298573      1      1         1
# 2    179.362140   Amarillo  5.631649      0      1         1
# 3    217.226796   Amarillo  8.166169      0      0         1
# 4    206.026740      Claro  7.444632      0      0         1
# ..          ...        ...       ...    ...    ...       ...
# 295  184.106741     Oscuro  3.981108      1      0         0
# 296  152.931749       Rojo  7.602139      1      1         0
# 297  167.488610  Muy claro  7.751694      0      0         1
# 298  138.016529      Verde  5.637248      1      1         1
# 299  161.101677   Amarillo  8.441367      0      1         1
#
# [300 rows x 6 columns]

# %% [markdown]
# ## One Hot Encoding

# %%
# Color
frutas = pd.get_dummies(frutas, columns=["Color"])

frutas
# Out:
#            Peso    Tamaño  Ácida  Dulce  Tropical  Color_Amarillo  \
# 0    202.921570  5.666598      0      1         1           False
# 1    162.004716  8.298573      1      1         1           False
# 2    179.362140  5.631649      0      1         1            True
# 3    217.226796  8.166169      0      0         1            True
# 4    206.026740  7.444632      0      0         1           False
# ..          ...       ...    ...    ...       ...             ...
# 295  184.106741  3.981108      1      0         0           False
# 296  152.931749  7.602139      1      1         0           False
# 297  167.488610  7.751694      0      0         1           False
# 298  138.016529  5.637248      1      1         1           False
# 299  161.101677  8.441367      0      1         1            True
#
#      Color_Claro  Color_Muy claro  Color_Muy oscuro  Color_Naranja  \
# 0          False            False             False          False
# ...

# %% [markdown]
# ## Reordenar columnas

# %%
frutas.columns
# Out:
# Index(['Peso', 'Tamaño', 'Ácida', 'Dulce', 'Tropical', 'Color_Amarillo',
#        'Color_Claro', 'Color_Muy claro', 'Color_Muy oscuro', 'Color_Naranja',
#        'Color_Oscuro', 'Color_Rojo', 'Color_Rojo claro', 'Color_Verde'],
#       dtype='object')

# %%
frutas = frutas.reindex(['Peso', 'Tamaño', 'Color_Amarillo',
       'Color_Claro', 'Color_Muy claro', 'Color_Muy oscuro', 'Color_Naranja',
       'Color_Oscuro', 'Color_Rojo', 'Color_Rojo claro', 'Color_Verde', 'Ácida', 'Dulce', 'Tropical'], axis=1)
frutas
# Out:
#            Peso    Tamaño  Color_Amarillo  Color_Claro  Color_Muy claro  \
# 0    202.921570  5.666598           False        False            False
# 1    162.004716  8.298573           False        False            False
# 2    179.362140  5.631649            True        False            False
# 3    217.226796  8.166169            True        False            False
# 4    206.026740  7.444632           False         True            False
# ..          ...       ...             ...          ...              ...
# 295  184.106741  3.981108           False        False            False
# 296  152.931749  7.602139           False        False            False
# 297  167.488610  7.751694           False        False             True
# 298  138.016529  5.637248           False        False            False
# 299  161.101677  8.441367            True        False            False
#
#      Color_Muy oscuro  Color_Naranja  Color_Oscuro  Color_Rojo  \
# ...
